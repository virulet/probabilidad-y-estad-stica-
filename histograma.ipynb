# %% [markdown]
# <a href="https://colab.research.google.com/github/virulet/probabilidad-y-estad-stica-/blob/main/histograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Primera practica**
#
# autor salvador **virulet**

# %% [markdown]
# # Nueva sección

# %%
print("hola mundo!")
# Out:
# hola mundo!

# %%
import matplotlib.pyplot as plt
import numpy as np
# Datos simulados (calificaciones de alumnos)
data = np.random.normal(loc=50, scale=12, size=500) # cambiamos al media a 50, la dispercion a 12 y los alubnos a 500
# Crear histograma
plt.hist(data, bins=20, color='orange', alpha=0.7, edgecolor='green')
plt.title('Histograma de Calificaciones')
plt.xlabel('Calificaciones')
plt.ylabel('Frecuencia')
plt.show()
